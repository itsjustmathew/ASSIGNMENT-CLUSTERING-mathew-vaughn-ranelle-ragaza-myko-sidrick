# %% [markdown]
# <a href="https://colab.research.google.com/github/itsjustmathew/ASSIGNMENT-CLUSTERING-mathew-vaughn-ranelle-ragaza-myko-sidrick/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Interpreting the Dendrogram:
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

# Generate random data for demonstration
np.random.seed(42)
data_points = np.random.rand(10, 2)

# Perform hierarchical clustering
linkage_matrix = linkage(data_points, method='ward')

# Plot the dendrogram
dendrogram(linkage_matrix, labels=range(1, 11), leaf_rotation=90)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data Points')
plt.ylabel('Height')
plt.show()
